# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
# 1. SCRAPING REVIEWS
# ==============================

def scrape_reviews():
    reviews = []
    
    url = "https://www.airlinequality.com/airline-reviews/air-algerie/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    review_blocks = soup.find_all("div", class_="text_content")

    for review in review_blocks:
        text = review.get_text(strip=True)
        reviews.append(text)

    return reviews


print("Scraping reviews...")
reviews = scrape_reviews()

df = pd.DataFrame(reviews, columns=["review"])
df.to_csv("data/reviews.csv", index=False)
print("Reviews saved!")
# Out:
# Scraping reviews...
# Reviews saved!

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options

# Chemin du navigateur Edge
edge_options = Options()
edge_options.binary_location = r"C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe"

# Chemin du EdgeDriver
service = Service(r"C:\edgedriver_win64\msedgedriver.exe")

# Lancement du navigateur
driver = webdriver.Edge(service=service, options=edge_options)

# Ouvre Google
driver.get("https://www.google.com")

print("Edge fonctionne correctement !")


driver.quit()
# Out:
# Edge fonctionne correctement !
